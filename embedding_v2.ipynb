# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

model_id = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    dtype=torch.float16,   # load weights in fp16
    device_map="auto"
)
model.eval()
# Out:
# /home/dkusmenko/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:736: UserWarning: Can't initialize amdsmi - Error code: 34
#   warnings.warn(f"Can't initialize amdsmi - Error code: {e.err_code}")
# Qwen2ForCausalLM(
#   (model): Qwen2Model(
#     (embed_tokens): Embedding(151936, 1536)
#     (layers): ModuleList(
#       (0-27): 28 x Qwen2DecoderLayer(
#         (self_attn): Qwen2Attention(
#           (q_proj): Linear(in_features=1536, out_features=1536, bias=True)
#           (k_proj): Linear(in_features=1536, out_features=256, bias=True)
#           (v_proj): Linear(in_features=1536, out_features=256, bias=True)
#           (o_proj): Linear(in_features=1536, out_features=1536, bias=False)
#         )
#         (mlp): Qwen2MLP(
#           (gate_proj): Linear(in_features=1536, out_features=8960, bias=False)
#           (up_proj): Linear(in_features=1536, out_features=8960, bias=False)
#           (down_proj): Linear(in_features=8960, out_features=1536, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): Qwen2RMSNorm((1536,), eps=1e-06)
#         (post_attention_layernorm): Qwen2RMSNorm((1536,), eps=1e-06)
#       )
#     )
#     (norm): Qwen2RMSNorm((1536,), eps=1e-06)
#     (rotary_emb): Qwen2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=1536, out_features=151936, bias=False)
# )

# %%
import torch
print(torch.cuda.is_available())           # this should say False on AMD
print(torch.backends.mps.is_available())   # Mac only, ignore on WSL
print(torch.version.hip)                   # should not be None on ROCm
print(torch.cuda.device_count())
print(torch.cuda.get_device_name())
# Out:
# True
# False
# 6.4.43484-123eb5128
# 1
# AMD Radeon RX 9070 XT

# %%
model.hf_device_map
# Out:
# {'': 0}

# %%
from pathlib import Path

# %%
BATCH_SIZE   = 16                # adjust to your GPU memory
OUT_DIR      = Path("/home/dkusmenko/research/embedding_v2.ipynb./embeddings")
OUT_DIR.mkdir(exist_ok=True, parents=True)
EMB_DTYPE    = np.float16        # save memory
MAX_TOKENS   = 512

# %%
def embedding_retrieval(prompt:str):
    # tokenize the input text
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    with torch.no_grad():
        out = model(**inputs, output_hidden_states=True)

    # take last hidden layer [B, T, D] in fp32
    last_layer = out.hidden_states[-1]

    # convert to float16 to save memory
    last_layer = last_layer.to(torch.float16)

    vec_mean  = last_layer.mean(dim=1)
    
    # return pooled embeddings as numpy array
    return vec_mean

# %%
embedding_retrieval("You are an auto insurance underwriter. A policyholder is from paris france and drives a renault. They are 25 years old. What is their risk level?")
# Out:
# /home/dkusmenko/.local/lib/python3.10/site-packages/transformers/integrations/sdpa_attention.py:96: UserWarning: Flash Efficient attention on Current AMD GPU is still experimental. Enable it with TORCH_ROCM_AOTRITON_ENABLE_EXPERIMENTAL=1. (Triggered internally at /pytorch/aten/src/ATen/native/transformers/hip/sdp_utils.cpp:256.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# /home/dkusmenko/.local/lib/python3.10/site-packages/transformers/integrations/sdpa_attention.py:96: UserWarning: Mem Efficient attention on Current AMD GPU is still experimental. Enable it with TORCH_ROCM_AOTRITON_ENABLE_EXPERIMENTAL=1. (Triggered internally at /pytorch/aten/src/ATen/native/transformers/hip/sdp_utils.cpp:302.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 embedding_retrieval("You are an auto insurance underwriter. A policyholder is from paris france and drives a renault. They are 25 years old. What is their risk level?")
#
# Cell In[5], line 14, in embedding_retrieval(prompt)
#      11 # convert to float16 to save memory
#      12 last_layer = last_layer.to(torch.float16)
# ---> 14 vec_mean  = last_layer.mean(dim=1).detach().numpy()
#      16 # return pooled embeddings as numpy array
#      17 return vec_mean
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %% [markdown]
# ### Load in Data

# %%
df = pd.read_csv("freMTPL2freq.csv")

# %% [markdown]
# ### Add Context

# %%
# Create frequency and claim index columns
df["Frequency"] = df["ClaimNb"]/df["Exposure"]
df["ClaimInd"] = df["ClaimNb"] >= 1

# %%
brand_mapping = {'B1': 'Renault, Nissan, or Citroen', 'B2': 'Renault, Nissan, or Citroen','B3': 'Volkswagen, Audi, Skoda, or Seat', 'B4': 'Opel, General Motors, or Ford', 'B5': 'Opel, General Motors, or Ford','B6': 'Fiat', 'B10':'Mercedes, Chrysler, or BMW', 'B11':'Mercedes, Chrysler, or BMW', 'B12': 'Japanese (except Nissan) or Korean', 'B13': 'Other','B14': 'Other' }

# %%
region_mapping = {
    "R11": "Île-de-France",
    "R21": "Champagne-Ardenne",
    "R22": "Picardie",
    "R23": "Haute-Normandie",
    "R24": "Centre",
    "R25": "Basse-Normandie",
    "R26": "Bourgogne",
    "R31": "Nord–Pas-de-Calais",
    "R41": "Lorraine",
    "R42": "Alsace",
    "R43": "Franche–Comté",
    "R52": "Pays de la Loire",
    "R53": "Bretagne",
    "R54": "Poitou–Charentes",
    "R72": "Aquitaine",
    "R73": "Midi–Pyrénées",
    "R74": "Limousin",
    "R82": "Rhône–Alpes",
    "R83": "Auvergne",
    "R91": "Languedoc–Roussillon",
    "R93": "Provence–Alpes–Côte d’Azur",
    "R94": "Corse"
}

# %%
area_mapping = {
    "A": "rural area",
    "B": "semi-rural area",
    "C": "suburban-fringe area",
    "D": "suburban area",
    "E": "urban area",
    "F": "urban center"
}

# %%
df["VehBrand"] = df["VehBrand"].map(brand_mapping)
df["Region"] = df["Region"].map(region_mapping)
df["Area"] = df["Area"].map(area_mapping)

# %% [markdown]
# ### Split to small portion of data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(["Frequency"], axis = 1), df["Frequency"], stratify= df["ClaimInd"], test_size=0.01, random_state=42)

# %%
X_test = X_test.reset_index(drop=True)

# %% [markdown]
# ### Create Prompts and Retreive Embeddings

# %% [markdown]
# Prompts have form:
#
# "You are an auto insurance underwriter. A policyholder is {X_test["DrivAge"][i]} years old and lives in a {X_test["Area"][i]} of {X_test["Region"][i]} in France, with a population density of {X_test["Density"][i]} people per square kilometer. They drive a {X_test["VehBrand"][i]} brand vehicle that is {X_test["VehAge"][i]} years old, which takes {X_test["VehGas"][i]} gas and is in power class {X_test["VehPower"][i]}. The policyholder has a Bonus-Malus score of {X_test["BonusMalus"][i]}. What is the risk level for this policyholder?"

# %%
prompt_list = []
for i in range(len(X_test)):
    prompt_list.append(f"You are an auto insurance underwriter. A policyholder is {X_test['DrivAge'][i]} years old and lives in a {X_test['Area'][i]} of {X_test['Region'][i]} in France, with a population density of {X_test['Density'][i]} people per square kilometer. They drive a {X_test['VehBrand'][i]} brand vehicle that is {X_test['VehAge'][i]} years old, which takes {X_test['VehGas'][i]} gas and is in power class {X_test['VehPower'][i]}. The policyholder has a Bonus-Malus score of {X_test['BonusMalus'][i]}. What is the risk level for this policyholder?")

# %%
def get_prompts():
    # Example dummy prompts
    for p in prompt_list:
        yield p

# ===== BATCH ITERATOR =====
def batch_iter(iterable, batch_size):
    buf = []
    for x in iterable:
        buf.append(x)
        if len(buf) == batch_size:
            yield buf
            buf = []
    if buf:
        yield buf

# ===== MAIN EXTRACTION LOOP =====
for batch_idx, batch_prompts in enumerate(batch_iter(get_prompts(), BATCH_SIZE)):
    # Tokenize & move to device
    inputs = tokenizer(
        batch_prompts,
        padding=True,
        truncation=True,
        max_length=MAX_TOKENS,
        return_tensors="pt"
    ).to(device)

    with torch.no_grad():
        outputs = model(**inputs, output_hidden_states=True)
        last_layer = outputs.hidden_states[-1]      # [B, T, H]
        embeddings = last_layer.mean(dim=1)         # mean pooling → [B, H]
        embeddings = embeddings.cpu().numpy().astype(EMB_DTYPE)

    # Save batch to disk
    np.save(OUT_DIR / f"batch_{batch_idx:06d}.npy", embeddings)
    print(f"Saved batch {batch_idx}, shape={embeddings.shape}")

print("✅ All embeddings extracted.")
# Out:
# /home/dkusmenko/.local/lib/python3.10/site-packages/transformers/integrations/sdpa_attention.py:96: UserWarning: Mem Efficient attention on Current AMD GPU is still experimental. Enable it with TORCH_ROCM_AOTRITON_ENABLE_EXPERIMENTAL=1. (Triggered internally at /pytorch/aten/src/ATen/native/transformers/hip/sdp_utils.cpp:302.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Saved batch 0, shape=(16, 1536)
# Saved batch 1, shape=(16, 1536)
# Saved batch 2, shape=(16, 1536)
# Saved batch 3, shape=(16, 1536)
# Saved batch 4, shape=(16, 1536)
# Saved batch 5, shape=(16, 1536)
# Saved batch 6, shape=(16, 1536)
# Saved batch 7, shape=(16, 1536)
# Saved batch 8, shape=(16, 1536)
# Saved batch 9, shape=(16, 1536)
# Saved batch 10, shape=(16, 1536)
# Saved batch 11, shape=(16, 1536)
# Saved batch 12, shape=(16, 1536)
# Saved batch 13, shape=(16, 1536)
# Saved batch 14, shape=(16, 1536)
# Saved batch 15, shape=(16, 1536)
# Saved batch 16, shape=(16, 1536)
# Saved batch 17, shape=(16, 1536)
# Saved batch 18, shape=(16, 1536)
# Saved batch 19, shape=(16, 1536)
# Saved batch 20, shape=(16, 1536)
# Saved batch 21, shape=(16, 1536)
# Saved batch 22, shape=(16, 1536)
# Saved batch 23, shape=(16, 1536)
# Saved batch 24, shape=(16, 1536)
# Saved batch 25, shape=(16, 1536)
# Saved batch 26, shape=(16, 1536)
# Saved batch 27, shape=(16, 1536)
# Saved batch 28, shape=(16, 1536)
# Saved batch 29, shape=(16, 1536)
# Saved batch 30, shape=(16, 1536)
# Saved batch 31, shape=(16, 1536)
# Saved batch 32, shape=(16, 1536)
# Saved batch 33, shape=(16, 1536)
# Saved batch 34, shape=(16, 1536)
# Saved batch 35, shape=(16, 1536)
# Saved batch 36, shape=(16, 1536)
# Saved batch 37, shape=(16, 1536)
# Saved batch 38, shape=(16, 1536)
# Saved batch 39, shape=(16, 1536)
# Saved batch 40, shape=(16, 1536)
# Saved batch 41, shape=(16, 1536)
# Saved batch 42, shape=(16, 1536)
# Saved batch 43, shape=(16, 1536)
# Saved batch 44, shape=(16, 1536)
# Saved batch 45, shape=(16, 1536)
# Saved batch 46, shape=(16, 1536)
# Saved batch 47, shape=(16, 1536)
# Saved batch 48, shape=(16, 1536)
# Saved batch 49, shape=(16, 1536)
# Saved batch 50, shape=(16, 1536)
# Saved batch 51, shape=(16, 1536)
# Saved batch 52, shape=(16, 1536)
# Saved batch 53, shape=(16, 1536)
# Saved batch 54, shape=(16, 1536)
# Saved batch 55, shape=(16, 1536)
# Saved batch 56, shape=(16, 1536)
# Saved batch 57, shape=(16, 1536)
# Saved batch 58, shape=(16, 1536)
# Saved batch 59, shape=(16, 1536)
# Saved batch 60, shape=(16, 1536)
# Saved batch 61, shape=(16, 1536)
# Saved batch 62, shape=(16, 1536)
# Saved batch 63, shape=(16, 1536)
# Saved batch 64, shape=(16, 1536)
# Saved batch 65, shape=(16, 1536)
# Saved batch 66, shape=(16, 1536)
# Saved batch 67, shape=(16, 1536)
# Saved batch 68, shape=(16, 1536)
# Saved batch 69, shape=(16, 1536)
# Saved batch 70, shape=(16, 1536)
# Saved batch 71, shape=(16, 1536)
# Saved batch 72, shape=(16, 1536)
# Saved batch 73, shape=(16, 1536)
# Saved batch 74, shape=(16, 1536)
# Saved batch 75, shape=(16, 1536)
# Saved batch 76, shape=(16, 1536)
# Saved batch 77, shape=(16, 1536)
# Saved batch 78, shape=(16, 1536)
# Saved batch 79, shape=(16, 1536)
# Saved batch 80, shape=(16, 1536)
# Saved batch 81, shape=(16, 1536)
# Saved batch 82, shape=(16, 1536)
# Saved batch 83, shape=(16, 1536)
# Saved batch 84, shape=(16, 1536)
# Saved batch 85, shape=(16, 1536)
# Saved batch 86, shape=(16, 1536)
# Saved batch 87, shape=(16, 1536)
# Saved batch 88, shape=(16, 1536)
# Saved batch 89, shape=(16, 1536)
# Saved batch 90, shape=(16, 1536)
# Saved batch 91, shape=(16, 1536)
# Saved batch 92, shape=(16, 1536)
# Saved batch 93, shape=(16, 1536)
# Saved batch 94, shape=(16, 1536)
# Saved batch 95, shape=(16, 1536)
# Saved batch 96, shape=(16, 1536)
# Saved batch 97, shape=(16, 1536)
# Saved batch 98, shape=(16, 1536)
# Saved batch 99, shape=(16, 1536)
# Saved batch 100, shape=(16, 1536)
# Saved batch 101, shape=(16, 1536)
# Saved batch 102, shape=(16, 1536)
# Saved batch 103, shape=(16, 1536)
# Saved batch 104, shape=(16, 1536)
# Saved batch 105, shape=(16, 1536)
# Saved batch 106, shape=(16, 1536)
# Saved batch 107, shape=(16, 1536)
# Saved batch 108, shape=(16, 1536)
# Saved batch 109, shape=(16, 1536)
# Saved batch 110, shape=(16, 1536)
# Saved batch 111, shape=(16, 1536)
# Saved batch 112, shape=(16, 1536)
# Saved batch 113, shape=(16, 1536)
# Saved batch 114, shape=(16, 1536)
# Saved batch 115, shape=(16, 1536)
# Saved batch 116, shape=(16, 1536)
# Saved batch 117, shape=(16, 1536)
# Saved batch 118, shape=(16, 1536)
# Saved batch 119, shape=(16, 1536)
# Saved batch 120, shape=(16, 1536)
# Saved batch 121, shape=(16, 1536)
# Saved batch 122, shape=(16, 1536)
# Saved batch 123, shape=(16, 1536)
# Saved batch 124, shape=(16, 1536)
# Saved batch 125, shape=(16, 1536)
# Saved batch 126, shape=(16, 1536)
# Saved batch 127, shape=(16, 1536)
# Saved batch 128, shape=(16, 1536)
# Saved batch 129, shape=(16, 1536)
# Saved batch 130, shape=(16, 1536)
# Saved batch 131, shape=(16, 1536)
# Saved batch 132, shape=(16, 1536)
# Saved batch 133, shape=(16, 1536)
# Saved batch 134, shape=(16, 1536)
# Saved batch 135, shape=(16, 1536)
# Saved batch 136, shape=(16, 1536)
# Saved batch 137, shape=(16, 1536)
# Saved batch 138, shape=(16, 1536)
# Saved batch 139, shape=(16, 1536)
# Saved batch 140, shape=(16, 1536)
# Saved batch 141, shape=(16, 1536)
# Saved batch 142, shape=(16, 1536)
# Saved batch 143, shape=(16, 1536)
# Saved batch 144, shape=(16, 1536)
# Saved batch 145, shape=(16, 1536)
# Saved batch 146, shape=(16, 1536)
# Saved batch 147, shape=(16, 1536)
# Saved batch 148, shape=(16, 1536)
# Saved batch 149, shape=(16, 1536)
# Saved batch 150, shape=(16, 1536)
# Saved batch 151, shape=(16, 1536)
# Saved batch 152, shape=(16, 1536)
# Saved batch 153, shape=(16, 1536)
# Saved batch 154, shape=(16, 1536)
# Saved batch 155, shape=(16, 1536)
# Saved batch 156, shape=(16, 1536)
# Saved batch 157, shape=(16, 1536)
# Saved batch 158, shape=(16, 1536)
# Saved batch 159, shape=(16, 1536)
# Saved batch 160, shape=(16, 1536)
# Saved batch 161, shape=(16, 1536)
# Saved batch 162, shape=(16, 1536)
# Saved batch 163, shape=(16, 1536)
# Saved batch 164, shape=(16, 1536)
# Saved batch 165, shape=(16, 1536)
# Saved batch 166, shape=(16, 1536)
# Saved batch 167, shape=(16, 1536)
# Saved batch 168, shape=(16, 1536)
# Saved batch 169, shape=(16, 1536)
# Saved batch 170, shape=(16, 1536)
# Saved batch 171, shape=(16, 1536)
# Saved batch 172, shape=(16, 1536)
# Saved batch 173, shape=(16, 1536)
# Saved batch 174, shape=(16, 1536)
# Saved batch 175, shape=(16, 1536)
# Saved batch 176, shape=(16, 1536)
# Saved batch 177, shape=(16, 1536)
# Saved batch 178, shape=(16, 1536)
# Saved batch 179, shape=(16, 1536)
# Saved batch 180, shape=(16, 1536)
# Saved batch 181, shape=(16, 1536)
# Saved batch 182, shape=(16, 1536)
# Saved batch 183, shape=(16, 1536)
# Saved batch 184, shape=(16, 1536)
# Saved batch 185, shape=(16, 1536)
# Saved batch 186, shape=(16, 1536)
# Saved batch 187, shape=(16, 1536)
# Saved batch 188, shape=(16, 1536)
# Saved batch 189, shape=(16, 1536)
# Saved batch 190, shape=(16, 1536)
# Saved batch 191, shape=(16, 1536)
# Saved batch 192, shape=(16, 1536)
# Saved batch 193, shape=(16, 1536)
# Saved batch 194, shape=(16, 1536)
# Saved batch 195, shape=(16, 1536)
# Saved batch 196, shape=(16, 1536)
# Saved batch 197, shape=(16, 1536)
# Saved batch 198, shape=(16, 1536)
# Saved batch 199, shape=(16, 1536)
# Saved batch 200, shape=(16, 1536)
# Saved batch 201, shape=(16, 1536)
# Saved batch 202, shape=(16, 1536)
# Saved batch 203, shape=(16, 1536)
# Saved batch 204, shape=(16, 1536)
# Saved batch 205, shape=(16, 1536)
# Saved batch 206, shape=(16, 1536)
# Saved batch 207, shape=(16, 1536)
# Saved batch 208, shape=(16, 1536)
# Saved batch 209, shape=(16, 1536)
# Saved batch 210, shape=(16, 1536)
# Saved batch 211, shape=(16, 1536)
# Saved batch 212, shape=(16, 1536)
# Saved batch 213, shape=(16, 1536)
# Saved batch 214, shape=(16, 1536)
# Saved batch 215, shape=(16, 1536)
# Saved batch 216, shape=(16, 1536)
# Saved batch 217, shape=(16, 1536)
# Saved batch 218, shape=(16, 1536)
# Saved batch 219, shape=(16, 1536)
# Saved batch 220, shape=(16, 1536)
# Saved batch 221, shape=(16, 1536)
# Saved batch 222, shape=(16, 1536)
# Saved batch 223, shape=(16, 1536)
# Saved batch 224, shape=(16, 1536)
# Saved batch 225, shape=(16, 1536)
# Saved batch 226, shape=(16, 1536)
# Saved batch 227, shape=(16, 1536)
# Saved batch 228, shape=(16, 1536)
# Saved batch 229, shape=(16, 1536)
# Saved batch 230, shape=(16, 1536)
# Saved batch 231, shape=(16, 1536)
# Saved batch 232, shape=(16, 1536)
# Saved batch 233, shape=(16, 1536)
# Saved batch 234, shape=(16, 1536)
# Saved batch 235, shape=(16, 1536)
# Saved batch 236, shape=(16, 1536)
# Saved batch 237, shape=(16, 1536)
# Saved batch 238, shape=(16, 1536)
# Saved batch 239, shape=(16, 1536)
# Saved batch 240, shape=(16, 1536)
# Saved batch 241, shape=(16, 1536)
# Saved batch 242, shape=(16, 1536)
# Saved batch 243, shape=(16, 1536)
# Saved batch 244, shape=(16, 1536)
# Saved batch 245, shape=(16, 1536)
# Saved batch 246, shape=(16, 1536)
# Saved batch 247, shape=(16, 1536)
# Saved batch 248, shape=(16, 1536)
# Saved batch 249, shape=(16, 1536)
# Saved batch 250, shape=(16, 1536)
# Saved batch 251, shape=(16, 1536)
# Saved batch 252, shape=(16, 1536)
# Saved batch 253, shape=(16, 1536)
# Saved batch 254, shape=(16, 1536)
# Saved batch 255, shape=(16, 1536)
# Saved batch 256, shape=(16, 1536)
# Saved batch 257, shape=(16, 1536)
# Saved batch 258, shape=(16, 1536)
# Saved batch 259, shape=(16, 1536)
# Saved batch 260, shape=(16, 1536)
# Saved batch 261, shape=(16, 1536)
# Saved batch 262, shape=(16, 1536)
# Saved batch 263, shape=(16, 1536)
# Saved batch 264, shape=(16, 1536)
# Saved batch 265, shape=(16, 1536)
# Saved batch 266, shape=(16, 1536)
# Saved batch 267, shape=(16, 1536)
# Saved batch 268, shape=(16, 1536)
# Saved batch 269, shape=(16, 1536)
# Saved batch 270, shape=(16, 1536)
# Saved batch 271, shape=(16, 1536)
# Saved batch 272, shape=(16, 1536)
# Saved batch 273, shape=(16, 1536)
# Saved batch 274, shape=(16, 1536)
# Saved batch 275, shape=(16, 1536)
# Saved batch 276, shape=(16, 1536)
# Saved batch 277, shape=(16, 1536)
# Saved batch 278, shape=(16, 1536)
# Saved batch 279, shape=(16, 1536)
# Saved batch 280, shape=(16, 1536)
# Saved batch 281, shape=(16, 1536)
# Saved batch 282, shape=(16, 1536)
# Saved batch 283, shape=(16, 1536)
# Saved batch 284, shape=(16, 1536)
# Saved batch 285, shape=(16, 1536)
# Saved batch 286, shape=(16, 1536)
# Saved batch 287, shape=(16, 1536)
# Saved batch 288, shape=(16, 1536)
# Saved batch 289, shape=(16, 1536)
# Saved batch 290, shape=(16, 1536)
# Saved batch 291, shape=(16, 1536)
# Saved batch 292, shape=(16, 1536)
# Saved batch 293, shape=(16, 1536)
# Saved batch 294, shape=(16, 1536)
# Saved batch 295, shape=(16, 1536)
# Saved batch 296, shape=(16, 1536)
# Saved batch 297, shape=(16, 1536)
# Saved batch 298, shape=(16, 1536)
# Saved batch 299, shape=(16, 1536)
# Saved batch 300, shape=(16, 1536)
# Saved batch 301, shape=(16, 1536)
# Saved batch 302, shape=(16, 1536)
# Saved batch 303, shape=(16, 1536)
# Saved batch 304, shape=(16, 1536)
# Saved batch 305, shape=(16, 1536)
# Saved batch 306, shape=(16, 1536)
# Saved batch 307, shape=(16, 1536)
# Saved batch 308, shape=(16, 1536)
# Saved batch 309, shape=(16, 1536)
# Saved batch 310, shape=(16, 1536)
# Saved batch 311, shape=(16, 1536)
# Saved batch 312, shape=(16, 1536)
# Saved batch 313, shape=(16, 1536)
# Saved batch 314, shape=(16, 1536)
# Saved batch 315, shape=(16, 1536)
# Saved batch 316, shape=(16, 1536)
# Saved batch 317, shape=(16, 1536)
# Saved batch 318, shape=(16, 1536)
# Saved batch 319, shape=(16, 1536)
# Saved batch 320, shape=(16, 1536)
# Saved batch 321, shape=(16, 1536)
# Saved batch 322, shape=(16, 1536)
# Saved batch 323, shape=(16, 1536)
# Saved batch 324, shape=(16, 1536)
# Saved batch 325, shape=(16, 1536)
# Saved batch 326, shape=(16, 1536)
# Saved batch 327, shape=(16, 1536)
# Saved batch 328, shape=(16, 1536)
# Saved batch 329, shape=(16, 1536)
# Saved batch 330, shape=(16, 1536)
# Saved batch 331, shape=(16, 1536)
# Saved batch 332, shape=(16, 1536)
# Saved batch 333, shape=(16, 1536)
# Saved batch 334, shape=(16, 1536)
# Saved batch 335, shape=(16, 1536)
# Saved batch 336, shape=(16, 1536)
# Saved batch 337, shape=(16, 1536)
# Saved batch 338, shape=(16, 1536)
# Saved batch 339, shape=(16, 1536)
# Saved batch 340, shape=(16, 1536)
# Saved batch 341, shape=(16, 1536)
# Saved batch 342, shape=(16, 1536)
# Saved batch 343, shape=(16, 1536)
# Saved batch 344, shape=(16, 1536)
# Saved batch 345, shape=(16, 1536)
# Saved batch 346, shape=(16, 1536)
# Saved batch 347, shape=(16, 1536)
# Saved batch 348, shape=(16, 1536)
# Saved batch 349, shape=(16, 1536)
# Saved batch 350, shape=(16, 1536)
# Saved batch 351, shape=(16, 1536)
# Saved batch 352, shape=(16, 1536)
# Saved batch 353, shape=(16, 1536)
# Saved batch 354, shape=(16, 1536)
# Saved batch 355, shape=(16, 1536)
# Saved batch 356, shape=(16, 1536)
# Saved batch 357, shape=(16, 1536)
# Saved batch 358, shape=(16, 1536)
# Saved batch 359, shape=(16, 1536)
# Saved batch 360, shape=(16, 1536)
# Saved batch 361, shape=(16, 1536)
# Saved batch 362, shape=(16, 1536)
# Saved batch 363, shape=(16, 1536)
# Saved batch 364, shape=(16, 1536)
# Saved batch 365, shape=(16, 1536)
# Saved batch 366, shape=(16, 1536)
# Saved batch 367, shape=(16, 1536)
# Saved batch 368, shape=(16, 1536)
# Saved batch 369, shape=(16, 1536)
# Saved batch 370, shape=(16, 1536)
# Saved batch 371, shape=(16, 1536)
# Saved batch 372, shape=(16, 1536)
# Saved batch 373, shape=(16, 1536)
# Saved batch 374, shape=(16, 1536)
# Saved batch 375, shape=(16, 1536)
# Saved batch 376, shape=(16, 1536)
# Saved batch 377, shape=(16, 1536)
# Saved batch 378, shape=(16, 1536)
# Saved batch 379, shape=(16, 1536)
# Saved batch 380, shape=(16, 1536)
# Saved batch 381, shape=(16, 1536)
# Saved batch 382, shape=(16, 1536)
# Saved batch 383, shape=(16, 1536)
# Saved batch 384, shape=(16, 1536)
# Saved batch 385, shape=(16, 1536)
# Saved batch 386, shape=(16, 1536)
# Saved batch 387, shape=(16, 1536)
# Saved batch 388, shape=(16, 1536)
# Saved batch 389, shape=(16, 1536)
# Saved batch 390, shape=(16, 1536)
# Saved batch 391, shape=(16, 1536)
# Saved batch 392, shape=(16, 1536)
# Saved batch 393, shape=(16, 1536)
# Saved batch 394, shape=(16, 1536)
# Saved batch 395, shape=(16, 1536)
# Saved batch 396, shape=(16, 1536)
# Saved batch 397, shape=(16, 1536)
# Saved batch 398, shape=(16, 1536)
# Saved batch 399, shape=(16, 1536)
# Saved batch 400, shape=(16, 1536)
# Saved batch 401, shape=(16, 1536)
# Saved batch 402, shape=(16, 1536)
# Saved batch 403, shape=(16, 1536)
# Saved batch 404, shape=(16, 1536)
# Saved batch 405, shape=(16, 1536)
# Saved batch 406, shape=(16, 1536)
# Saved batch 407, shape=(16, 1536)
# Saved batch 408, shape=(16, 1536)
# Saved batch 409, shape=(16, 1536)
# Saved batch 410, shape=(16, 1536)
# Saved batch 411, shape=(16, 1536)
# Saved batch 412, shape=(16, 1536)
# Saved batch 413, shape=(16, 1536)
# Saved batch 414, shape=(16, 1536)
# Saved batch 415, shape=(16, 1536)
# Saved batch 416, shape=(16, 1536)
# Saved batch 417, shape=(16, 1536)
# Saved batch 418, shape=(16, 1536)
# Saved batch 419, shape=(16, 1536)
# Saved batch 420, shape=(16, 1536)
# Saved batch 421, shape=(16, 1536)
# Saved batch 422, shape=(16, 1536)
# Saved batch 423, shape=(13, 1536)
# ✅ All embeddings extracted.

# %%
import numpy as np
from pathlib import Path

# folder that contains all saved .npy batches
EMB_DIR = Path("/home/dkusmenko/research/embedding_v2.ipynb./embeddings")  # change to your folder

# get all batch files
files = sorted(EMB_DIR.glob("*.npy"))

all_embs = []
for f in files:
    arr = np.load(f)
    all_embs.append(arr)

# stack into one big matrix
emb_matrix = np.vstack(all_embs)
print("Final shape:", emb_matrix.shape)

# optionally save once as a single file
np.save(EMB_DIR / "all_embeddings.npy", emb_matrix)
# Out:
# Final shape: (6781, 1536)

# %%
indtest = np.array([np.array(X_test["ClaimInd"])]).T

# %%
new_X = np.hstack((emb_matrix, indtest))

# %%
pdX = pd.DataFrame(new_X)

# %% [markdown]
# ### Perform PCA to have dim 44

# %%
#stratified pca
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(pdX.drop([1536], axis = 1), y_test, stratify = pdX[1536], test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train2s = scaler.fit_transform(X_train2)
X_test2s = scaler.transform(X_test2)

pca = PCA(n_components=44)
X_train2pc = pca.fit_transform(X_train2s)
X_test2pc = pca.transform(X_test2s)

# %% [markdown]
# ### Fit GLM to Model

# %%
from sklearn.linear_model import PoissonRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'alpha': [0.0, 0.1, 1.0, 5.0, 10.0, 20.0]}
grid = GridSearchCV(PoissonRegressor(max_iter=1000), param_grid, cv=5)
grid.fit(X_train2pc, y_train2)

print("Best alpha:", grid.best_params_['alpha'])
# Out:
# Best alpha: 10.0

# %%
import numpy as np
from sklearn.linear_model import PoissonRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

model = PoissonRegressor(alpha=grid.best_params_['alpha'], max_iter=10000)
model.fit(X_train2pc, y_train2)
# Out:
# PoissonRegressor(alpha=10.0, max_iter=10000)

# %%
from sklearn.metrics import mean_poisson_deviance

y_pred = model.predict(X_test2pc)
mpd = mean_poisson_deviance(y_test2, y_pred)
print("Mean Poisson Deviance:", mpd)
# Out:
# Mean Poisson Deviance: 1.7268213263535712

# %% [markdown]
# ### Textbook Model

# %%
freq = np.array([np.array(y_test)]).T

# %%
red_X = np.hstack((X_test, freq))

# %%
new_Xred = pd.DataFrame(red_X, columns=['IDpol', 'ClaimNb', 'Exposure','Area','VehPower','VehAge','DrvAge','BonusMalus','VehBrand','VehGas','Density','Region','ClaimInd','Frequency'])

# %%
dat = new_Xred

# %%
dat = pd.get_dummies(dat, columns=['VehGas'],drop_first=True)
dat = pd.get_dummies(dat, columns=['VehBrand'],drop_first=True)
dat = pd.get_dummies(dat, columns=['Region'],drop_first=True)

# %%
area_remapping = {
    "rural area": 1,
    "semi-rural area": 2,
    "suburban-fringe area": 3,
    "suburban area": 4,
    "urban area": 5,
    "urban center": 6
}

# %%
import pandas as pd
import numpy as np

# Assuming dat is a pandas DataFrame
dat["Area"] = dat["Area"].map(area_remapping)

dat['VehPowerGLM'] = pd.Categorical(np.minimum(dat['VehPower'], 9))

dat['VehAgeGLM'] = pd.cut(
    dat['VehAge'],
    bins=[0, 5, 12, 101],
    labels=["0-5", "6-12", "12+"],
    include_lowest=True
)

dat['DrivAgeGLM'] = pd.cut(
    dat['DrvAge'],
    bins=[18, 20, 25, 30, 40, 50, 70, 101],
    labels=["18-20", "21-25", "26-30", "31-40", "41-50", "51-70", "71+"],
    include_lowest=True
)

dat['BonusMalusGLM'] = np.minimum(dat['BonusMalus'], 150)

dat['DensityGLM'] = np.log(dat["Density"].astype(float))

# %%
dat = pd.get_dummies(dat, columns=['DrivAgeGLM'],drop_first=True)
dat = pd.get_dummies(dat, columns=['VehAgeGLM'],drop_first=True)
dat = pd.get_dummies(dat, columns=['VehPowerGLM'],drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_traindat, X_testdat, y_traindat, y_testdat = train_test_split(dat.drop(["IDpol", "ClaimNb", "Exposure", "Frequency", "ClaimInd", "VehPower", "VehAge", "DrvAge", "BonusMalus","Density"], axis = 1), dat["Frequency"], stratify= dat["ClaimInd"], test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import PoissonRegressor
from sklearn.model_selection import GridSearchCV

param_grid2 = {'alpha': [0.1, 1.0, 5.0, 10.0, 20.0]}
grid2 = GridSearchCV(PoissonRegressor(max_iter=10000), param_grid2, cv=5)
grid2.fit(X_traindat, y_traindat)

print("Best alpha:", grid2.best_params_['alpha'])
# Out:
# Best alpha: 0.1

# %%
import numpy as np
from sklearn.linear_model import PoissonRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

modelbook = PoissonRegressor(alpha=0.1, max_iter=1000)
modelbook.fit(X_traindat, y_traindat)
# Out:
# PoissonRegressor(alpha=0.1, max_iter=1000)

# %%
from sklearn.metrics import mean_poisson_deviance

y_pred_book = modelbook.predict(X_testdat)
mpdbook = mean_poisson_deviance(y_testdat, y_pred_book)
print("Mean Poisson Deviance:", mpdbook)
# Out:
# Mean Poisson Deviance: 1.8761265806342542
